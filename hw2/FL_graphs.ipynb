# %%
from matplotlib import pyplot as plt
from glob import glob
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8,3)

# %%
"""
Note: To generated the graphs using this notebook, please move the csv files from "out/" folder to a new folder named "results/". 
This notebook and the "results/" folder should be in the same parent folder.
"""

paths = glob('results/*.csv')

# %%
## sanity check
df = pd.read_csv('results/tiny_imagenet_acc_metrics__exp2_part2.csv')
# df = pd.read_csv(paths[0])

df['test_before']
df
# Out:
#     test_before  test_after
# 0      0.724016   74.302177
# 1      0.974186   74.496071
# 2      1.402834   74.580086
# 3      1.254473   76.552307
# 4      1.351063   75.347389
# ..          ...         ...
# 95     8.404290   80.710640
# 96     7.653130   81.083855
# 97     8.022558   81.971985
# 98     8.497884   81.342560
# 99     8.639474   80.357460
#
# [100 rows x 2 columns]

# %%
## exp2_part1

print('test_before')
for a in [0.1, 0.5, 1.0, 4.0]:
    path = f'results/tiny_imagenet_acc_metrics__exp2_part1_{a}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,100,1)
    plt.plot(x_ticks, df['test_before'], label=f'alpha={a}')
#     plt.plot(x_ticks, df['test_after'])
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


print('test_after')
for a in [0.1, 0.5, 1.0, 4.0]:
    path = f'results/tiny_imagenet_acc_metrics__exp2_part1_{a}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,100,1)
#     plt.plot(x_ticks, df['test_before'], label=f'alpha={a}')
    plt.plot(x_ticks, df['test_after'], label=f'alpha={a}')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# test_before
# test_after

# %%
## exp2_part2

print('test_before')
path = f'results/tiny_imagenet_acc_metrics__exp2_part2.csv'
print(path)
df = pd.read_csv(path)
x_ticks = np.arange(0,100,1)
plt.plot(x_ticks, df['test_before'], label=f'test_before')
plt.plot(x_ticks, df['test_after'], label=f'test_after')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# test_before
# results/tiny_imagenet_acc_metrics__exp2_part2.csv

# %%
## exp3

le = [1, 5, 10, 50, 100, 500] # default: 5
ge = [500, 100, 50, 10, 5, 1] # default: 100

print('test_before')
for i in range(len(le)):
    path = f'results/tiny_imagenet_acc_metrics__exp3_{le[i]}_{ge[i]}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,df.shape[0],1)
    plt.plot(x_ticks, df['test_before'], label=f'le={le[i]}, ge={ge[i]}')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


print('test_after')
for i in range(len(le)):
    path = f'results/tiny_imagenet_acc_metrics__exp3_{le[i]}_{ge[i]}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,df.shape[0],1)
    plt.plot(x_ticks, df['test_after'], label=f'le={le[i]}, ge={ge[i]}')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# test_before
# test_after

# %%
## exp4

mu = [0.0, 0.1, 0.3, 0.7, 1.0, 4.0] ## default: 1.0

print('test_before')
for i in range(len(mu)):
    path = f'results/tiny_imagenet_acc_metrics__exp4_{mu[i]}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,df.shape[0],1)
    plt.plot(x_ticks, df['test_before'], label=f'mu={mu[i]}')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


print('test_after')
for i in range(len(mu)):
    path = f'results/tiny_imagenet_acc_metrics__exp4_{mu[i]}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,df.shape[0],1)
    plt.plot(x_ticks, df['test_after'], label=f'mu={mu[i]}')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# test_before
# test_after

# %%
## exp1_part1

cn = [20, 70, 100, 200] # default: 20; in given sample cmd: 100

print('test_before')
for i in range(len(cn)):
    path = f'results/tiny_imagenet_acc_metrics__exp1_part1_{cn[i]}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,df.shape[0],1)
    plt.plot(x_ticks, df['test_before'], label=f'cn={cn[i]}')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


print('test_after')
for i in range(len(cn)):
    path = f'results/tiny_imagenet_acc_metrics__exp1_part1_{cn[i]}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,df.shape[0],1)
    plt.plot(x_ticks, df['test_after'], label=f'cn={cn[i]}')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# test_before
# test_after

# %%
## exp1_part2

jr = [0.1, 0.4, 0.7, 1.0] # default: 0.1; in given sample cmd: .4

print('test_before')
for i in range(len(jr)):
    path = f'results/tiny_imagenet_acc_metrics__exp1_part2_{jr[i]}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,df.shape[0],1)
    plt.plot(x_ticks, df['test_before'], label=f'jr={jr[i]}')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


print('test_after')
for i in range(len(jr)):
    path = f'results/tiny_imagenet_acc_metrics__exp1_part2_{jr[i]}.csv'
#     print(path)
    df = pd.read_csv(path)
    x_ticks = np.arange(0,df.shape[0],1)
    plt.plot(x_ticks, df['test_after'], label=f'jr={jr[i]}')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()
plt.show()
# Out:
# test_before
# test_after
